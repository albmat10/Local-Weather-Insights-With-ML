# %%
import pandas as pd

# %%
weather = pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                          NAME  ACMH  ACSH   AWND  \
# DATE
# 1960-01-01  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# 1960-01-02  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# 1960-01-03  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# 1960-01-04  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# 1960-01-05  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# ...                 ...                           ...   ...   ...    ...
# 2024-08-22  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN  12.08
# 2024-08-23  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN  13.87
# 2024-08-24  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN  12.97
# 2024-08-25  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
# 2024-08-26  USW00003927  DAL FTW WSCMO AIRPORT, TX US   NaN   NaN    NaN
#
#             FMTM  GAHT    PGTM  PRCP  PSUN  ...  WT13  WT14  WT15  WT16  WT17  \
# DATE                                        ...
# 1960-01-01   NaN -14.6   536.0  0.04   NaN  ...   NaN   NaN   NaN   1.0   NaN
# 1960-01-02   NaN -11.8  1542.0  0.05   NaN  ...   NaN   NaN   NaN   1.0   NaN
# 1960-01-03   NaN -11.8   106.0  0.00   NaN  ...   NaN   NaN   NaN   1.0   NaN
# 1960-01-04   NaN  -9.4  1354.0  0.21   NaN  ...   NaN   NaN   NaN   1.0   NaN
# 1960-01-05   NaN -18.1  1248.0  1.28   NaN  ...   NaN   NaN   NaN   1.0   NaN
# ...          ...   ...     ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2024-08-22   NaN   NaN     NaN  0.00   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2024-08-23   NaN   NaN     NaN  0.00   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2024-08-24   NaN   NaN     NaN  0.00   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2024-08-25   NaN   NaN     NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2024-08-26   NaN   NaN     NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT21  WT22  WV03
# DATE
# 1960-01-01   NaN   NaN   NaN   NaN   NaN
# 1960-01-02   NaN   NaN   NaN   NaN   NaN
# 1960-01-03   NaN   NaN   NaN   NaN   NaN
# 1960-01-04   1.0   NaN   NaN   NaN   NaN
# 1960-01-05   1.0   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2024-08-22   NaN   NaN   NaN   NaN   NaN
# 2024-08-23   NaN   NaN   NaN   NaN   NaN
# 2024-08-24   NaN   NaN   NaN   NaN   NaN
# 2024-08-25   NaN   NaN   NaN   NaN   NaN
# 2024-08-26   NaN   NaN   NaN   NaN   NaN
#
# [23615 rows x 46 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.521872
# ACSH       0.521872
# AWND       0.371459
# FMTM       0.570188
# GAHT       0.922803
# PGTM       0.240271
# PRCP       0.000085
# PSUN       0.922676
# SNOW       0.000593
# SNWD       0.144315
# TAVG       0.710354
# TMAX       0.000085
# TMIN       0.000085
# TSUN       0.685073
# WDF1       0.522083
# WDF2       0.555791
# WDF5       0.557146
# WDFG       0.450349
# WESD       0.998645
# WSF1       0.522041
# WSF2       0.555791
# WSF5       0.557146
# WSFG       0.450222
# WT01       0.787042
# WT02       0.976075
# WT03       0.869532
# WT04       0.992462
# WT05       0.996104
# WT06       0.992335
# WT07       0.998391
# WT08       0.901546
# WT09       0.999661
# WT10       0.999958
# WT11       0.998094
# WT13       0.934194
# WT14       0.976159
# WT15       0.998433
# WT16       0.755367
# WT17       0.998518
# WT18       0.988821
# WT19       0.999619
# WT21       0.999831
# WT22       0.999746
# WV03       0.999915
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()

# %%
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01    0.04   0.0         0.0      45.0      39.0
# 1960-01-02    0.05   0.0         0.0      55.0      34.0
# 1960-01-03    0.00   0.0         0.0      41.0      28.0
# 1960-01-04    0.21   0.1         0.0      39.0      32.0
# 1960-01-05    1.28   0.8         0.0      38.0      32.0
# ...            ...   ...         ...       ...       ...
# 2024-08-22    0.00   0.0         0.0     101.0      79.0
# 2024-08-23    0.00   0.0         0.0     103.0      82.0
# 2024-08-24    0.00   0.0         0.0      98.0      80.0
# 2024-08-25     NaN   NaN         NaN       NaN       NaN
# 2024-08-26     NaN   NaN         NaN       NaN       NaN
#
# [23615 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.000085
# snow          0.000593
# snow_depth    0.144315
# temp_max      0.000085
# temp_min      0.000085
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# snow
# 0.0     23472
# 0.1        17
# 0.2        15
# 0.4        13
# 0.3        12
# 1.2         7
# 0.5         6
# 1.0         6
# 2.0         6
# 1.5         5
# 0.8         5
# 1.1         4
# 1.4         4
# 2.5         3
# 2.6         3
# 1.3         3
# 2.4         2
# 3.7         2
# 4.0         2
# 0.6         2
# 0.7         2
# 1.7         1
# 11.2        1
# 3.0         1
# 3.5         1
# 4.7         1
# 7.5         1
# 1.6         1
# 4.3         1
# 7.8         1
# 0.9         1
# Name: count, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 0.0     20106
# 1.0        40
# 2.0        29
# 3.0         8
# 1.2         7
# 4.0         5
# 5.0         3
# 3.9         3
# 3.1         3
# 6.0         1
# 8.0         1
# 11.0        1
# Name: count, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2024-08-25     NaN   NaN         NaN       NaN       NaN
# 2024-08-26     NaN   NaN         NaN       NaN       NaN

# %%
core_weather.loc["1983-10-20":"1983-11-05",:]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1983-10-20    0.37   0.0         0.0      81.0      60.0
# 1983-10-21    0.00   0.0         0.0      64.0      57.0
# 1983-10-22    0.00   0.0         0.0      68.0      52.0
# 1983-10-23    0.00   0.0         0.0      70.0      50.0
# 1983-10-24    0.00   0.0         0.0      77.0      47.0
# 1983-10-25    0.00   0.0         0.0      67.0      52.0
# 1983-10-26    0.00   0.0         0.0      71.0      44.0
# 1983-10-27    0.00   0.0         0.0      76.0      44.0
# 1983-10-28    0.00   0.0         0.0      77.0      45.0
# 1983-10-29    0.00   0.0         0.0      77.0      56.0
# 1983-10-30    0.00   0.0         0.0      79.0      54.0
# 1983-10-31    0.00   0.0         0.0      79.0      55.0
# 1983-11-01    0.00   0.0         0.0      81.0      61.0
# 1983-11-02    0.00   0.0         0.0      83.0      68.0
# 1983-11-03    0.00   0.0         0.0      81.0      66.0
# 1983-11-04    0.00   0.0         0.0      79.0      62.0
# 1983-11-05    0.58   0.0         0.0      64.0      57.0

# %%
core_weather["precip"].value_counts()
# Out:
# precip
# 0.00    18518
# 0.01      486
# 0.02      307
# 0.03      225
# 0.05      172
#         ...
# 2.96        1
# 2.56        1
# 4.22        1
# 3.48        1
# 1.54        1
# Name: count, Length: 301, dtype: int64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather[pd.isnull(core_weather["temp_max"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2024-08-25     0.0   NaN         NaN       NaN       NaN
# 2024-08-26     0.0   NaN         NaN       NaN       NaN

# %%
core_weather = core_weather.fillna(method="ffill")
# Out:
# /var/folders/b4/d4n1wr615rnfjsn8846280_40000gn/T/ipykernel_46120/3127936549.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.0
# snow          0.0
# snow_depth    0.0
# temp_max      0.0
# temp_min      0.0
# dtype: float64

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2024-08-17', '2024-08-18', '2024-08-19', '2024-08-20', '2024-08-21',
#        '2024-08-22', '2024-08-23', '2024-08-24', '2024-08-25', '2024-08-26'],
#       dtype='object', name='DATE', length=23615)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2024-08-17', '2024-08-18', '2024-08-19', '2024-08-20',
#                '2024-08-21', '2024-08-22', '2024-08-23', '2024-08-24',
#                '2024-08-25', '2024-08-26'],
#               dtype='datetime64[ns]', name='DATE', length=23615, freq=None)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip        0
# snow          0
# snow_depth    0
# temp_max      0
# temp_min      0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1960    24.97
# 1961    30.58
# 1962    41.43
# 1963    20.46
# 1964    34.31
#         ...
# 2020    43.70
# 2021    33.60
# 2022    36.64
# 2023    29.31
# 2024    31.64
# Name: precip, Length: 65, dtype: float64

# %%
core_weather["target"] =core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-01-01    0.04   0.0         0.0      45.0      39.0    55.0
# 1960-01-02    0.05   0.0         0.0      55.0      34.0    41.0
# 1960-01-03    0.00   0.0         0.0      41.0      28.0    39.0
# 1960-01-04    0.21   0.1         0.0      39.0      32.0    38.0
# 1960-01-05    1.28   0.8         0.0      38.0      32.0    37.0
# ...            ...   ...         ...       ...       ...     ...
# 2024-08-22    0.00   0.0         0.0     101.0      79.0   103.0
# 2024-08-23    0.00   0.0         0.0     103.0      82.0    98.0
# 2024-08-24    0.00   0.0         0.0      98.0      80.0    98.0
# 2024-08-25    0.00   0.0         0.0      98.0      80.0    98.0
# 2024-08-26    0.00   0.0         0.0      98.0      80.0     NaN
#
# [23615 rows x 6 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-01-01    0.04   0.0         0.0      45.0      39.0    55.0
# 1960-01-02    0.05   0.0         0.0      55.0      34.0    41.0
# 1960-01-03    0.00   0.0         0.0      41.0      28.0    39.0
# 1960-01-04    0.21   0.1         0.0      39.0      32.0    38.0
# 1960-01-05    1.28   0.8         0.0      38.0      32.0    37.0
# ...            ...   ...         ...       ...       ...     ...
# 2024-08-21    0.00   0.0         0.0      97.0      78.0   101.0
# 2024-08-22    0.00   0.0         0.0     101.0      79.0   103.0
# 2024-08-23    0.00   0.0         0.0     103.0      82.0    98.0
# 2024-08-24    0.00   0.0         0.0      98.0      80.0    98.0
# 2024-08-25    0.00   0.0         0.0      98.0      80.0    98.0
#
# [23614 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2024-07-31"]

# %%
test =core_weather.loc["2024-08-01":]

# %%
reg.fit(train[predictors], train['target'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# np.float64(2.9721388651237817)

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2024-08-01   102.0    97.685537
# 2024-08-02    99.0    99.277667
# 2024-08-03    97.0    95.526842
# 2024-08-04    97.0    95.929926
# 2024-08-05   101.0    95.929926
# 2024-08-06   103.0    98.608119
# 2024-08-07   103.0   100.453282
# 2024-08-08    90.0   100.959348
# 2024-08-09    97.0    91.401922
# 2024-08-10    96.0    95.423860
# 2024-08-11    98.0    96.272510
# 2024-08-12   100.0    97.358574
# 2024-08-13   100.0    98.950703
# 2024-08-14   101.0    98.950703
# 2024-08-15   102.0    99.620252
# 2024-08-16   101.0   100.795866
# 2024-08-17   104.0    99.873285
# 2024-08-18   107.0   101.628896
# 2024-08-19   104.0   104.143607
# 2024-08-20    97.0   102.134963
# 2024-08-21   101.0    96.182959
# 2024-08-22   103.0    99.114185
# 2024-08-23    98.0   101.212381
# 2024-08-24    98.0    97.358574
# 2024-08-25    98.0    97.358574

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.35499338,  0.66954822,  0.25303317])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2024-07-31"]
    test = core_weather.loc["2024-08-01":]
    reg.fit(train[predictors], train['target'])
    predictions = reg.predict(test[predictors])
    error = mean_absolute_error(test['target'], predictions)
    combined = pd.concat([test['target'], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    
    return error, combined

# %%
core_weather["month_max"]= core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target  month_max
# DATE
# 1960-01-01    0.04   0.0         0.0      45.0      39.0    55.0        NaN
# 1960-01-02    0.05   0.0         0.0      55.0      34.0    41.0        NaN
# 1960-01-03    0.00   0.0         0.0      41.0      28.0    39.0        NaN
# 1960-01-04    0.21   0.1         0.0      39.0      32.0    38.0        NaN
# 1960-01-05    1.28   0.8         0.0      38.0      32.0    37.0        NaN
# ...            ...   ...         ...       ...       ...     ...        ...
# 2024-08-21    0.00   0.0         0.0      97.0      78.0   101.0  97.766667
# 2024-08-22    0.00   0.0         0.0     101.0      79.0   103.0  98.233333
# 2024-08-23    0.00   0.0         0.0     103.0      82.0    98.0  98.600000
# 2024-08-24    0.00   0.0         0.0      98.0      80.0    98.0  98.800000
# 2024-08-25    0.00   0.0         0.0      98.0      80.0    98.0  99.166667
#
# [23614 rows x 7 columns]

# %%
core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

# %%
core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
predictors=["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# np.float64(2.915158354015216)

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather.groupby(core_weather.index.month)["temp_max"].transform(lambda x: x.expanding().mean())

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target  month_max  \
# DATE
# 1960-01-31    0.00   0.0         0.0      60.0      30.0    69.0  53.400000
# 1960-02-01    0.00   0.0         0.0      69.0      42.0    61.0  53.866667
# 1960-02-02    0.00   0.0         0.0      61.0      50.0    59.0  54.533333
# 1960-02-03    0.88   0.0         0.0      59.0      47.0    53.0  55.200000
# 1960-02-04    0.12   0.0         0.0      53.0      41.0    48.0  55.700000
# ...            ...   ...         ...       ...       ...     ...        ...
# 2024-08-21    0.00   0.0         0.0      97.0      78.0   101.0  97.766667
# 2024-08-22    0.00   0.0         0.0     101.0      79.0   103.0  98.233333
# 2024-08-23    0.00   0.0         0.0     103.0      82.0    98.0  98.600000
# 2024-08-24    0.00   0.0         0.0      98.0      80.0    98.0  98.800000
# 2024-08-25    0.00   0.0         0.0      98.0      80.0    98.0  99.166667
#
#             month_day_max   max_min  monthly_avg
# DATE
# 1960-01-31       0.890000  2.000000    60.000000
# 1960-02-01       0.780676  1.642857    69.000000
# 1960-02-02       0.893989  1.220000    65.000000
# 1960-02-03       0.935593  1.255319    63.000000
# 1960-02-04       1.050943  1.292683    60.500000
# ...                   ...       ...          ...
# 2024-08-21       1.007904  1.243590    96.094763
# 2024-08-22       0.972607  1.278481    96.097208
# 2024-08-23       0.957282  1.256098    96.100648
# 2024-08-24       1.008163  1.225000    96.101594
# 2024-08-25       1.011905  1.225000    96.102539
#
# [23584 rows x 10 columns]

# %%
core_weather["day_of_year_avg"] =  core_weather["temp_max"].groupby(core_weather.index.day_of_year).transform(lambda x: x.expanding(1).mean())

# %%
predictors=["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min", "day_of_year_avg", "monthly_avg"]

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# np.float64(2.679712379777862)

# %%
reg.coef_
# Out:
# array([-2.72681198,  0.41210245,  0.08171216,  0.1807943 , -8.8927776 ,
#         0.29295841,  0.14501404,  0.16694672])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.082183
# snow              -0.105162
# snow_depth        -0.112692
# temp_max           0.895946
# temp_min           0.852243
# target             1.000000
# month_max          0.820599
# month_day_max     -0.416708
# max_min           -0.321250
# monthly_avg        0.834639
# day_of_year_avg    0.847935
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head()
# Out:
#             actual  predictions       diff
# DATE
# 2024-08-08    90.0   100.612291  10.612291
# 2024-08-18   107.0   100.961705   6.038295
# 2024-08-17   104.0    99.393111   4.606889
# 2024-08-20    97.0   101.167016   4.167016
# 2024-08-06   103.0    99.037275   3.962725
